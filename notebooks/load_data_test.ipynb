# %%
import pandas as pd

# %%
import geopandas as gpd

gdf = gpd.read_file("../data/gis_layers/Barcelona_Sensors_Enriched.geojson")
gdf.head()
# Out:
#    Id_Instal  Longitud    Latitud  Avg_Noise_dB  Min_Noise_dB  Max_Noise_dB  \
# 0        186  2.152752  41.395450     65.366429          49.6          77.4
# 1        187  2.151563  41.396156     63.641071          47.0          72.1
# 2        206  2.176924  41.380127     59.071007          45.6          69.6
# 3        207  2.173348  41.378273     63.500347          54.6          74.2
# 4        208  2.182772  41.384925     59.998370          43.7          80.3
#
#    dist_to_park_m  dist_to_mainroad_m  nearest_node  street_centrality  \
# 0       74.885184          857.295394    5094317308           0.005271
# 1      140.390370          932.751916      30556617           0.005223
# 2      291.422265          458.044196      30243946           0.004860
# 3      138.777978          646.539057      30227025           0.000368
# 4      222.206750          535.684311   13197779092           0.000485
#
#    Avg_Noise_dB_localmean_150.0m                  geometry
# ...
